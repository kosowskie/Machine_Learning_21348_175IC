# %%
import pandas as pd
from pandasgui import show

# %% [markdown]
# Pobieranie

# %%
df = pd.read_csv("D:\Studia\Machine Learning\Lab2\samochody1tys.csv")

df
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %% [markdown]
# GUI Pandas

# %%
show(df)

# %% [markdown]
# Zamiana kolumny w rzędy

# %%
pd.melt(df)
# Out:
#          variable        value
# 0              id            0
# 1              id            1
# 2              id            2
# 3              id            3
# 4              id            4
# ...           ...          ...
# 8995  wojewodztwo  Małopolskie
# 8996  wojewodztwo    Lubelskie
# 8997  wojewodztwo      Łódzkie
# 8998  wojewodztwo  Małopolskie
# 8999  wojewodztwo  Małopolskie
#
# [9000 rows x 2 columns]

# %% [markdown]
# Zmiana nazw kolumn

# %%
df.rename(columns={'id':'id', 'marka':'marka','rok_produkcji':'rok_produkcji','rodzaj_silnika':'rodzaj_silnika','pojemnosc_silnika':'pojemnosc_silnika','przebieg':'przebieg','cena':'cena','wojewodztwo':'wojewodztwo'})
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %% [markdown]
# Sortowanie po roku produkcji od najmłodszego

# %%
df.sort_values('rok_produkcji', ascending=False)
# Out:
#       id          marka         model  rok_produkcji rodzaj_silnika  \
# 638  638           Opel    Insignia B         2017.0        Benzyna
# 728  728           Opel         Mokka         2017.0        Benzyna
# 742  742           Mini    Countryman         2017.0         Diesel
# 740  740            BMW        X6 F16         2017.0         Diesel
# 738  738        Hyundai     Tucson II         2017.0         Diesel
# ..   ...            ...           ...            ...            ...
# 990  990  Mercedes-Benz  Klasa S W126         1986.0    Benzyna+LPG
# 484  484           Opel       Senator         1986.0        Benzyna
# 130  130  Mercedes-Benz  Klasa S W126         1984.0        Benzyna
# 704  704  Mercedes-Benz  Klasa S W126         1984.0        Benzyna
# 611  611      Chevrolet        Camaro         1979.0        Benzyna
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 638             1500.0       2.0  116850.0         Śląskie
# ...

# %% [markdown]
# Stworzenie wykresu

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Usuwanie kolumny

# %%
df.drop(columns='rodzaj_silnika')
# Out:
#       id       marka        model  rok_produkcji  pojemnosc_silnika  przebieg  \
# 0      0      Nissan  X-Trail III         2014.0             1600.0  160000.0
# 1      1         BMW       X1 E84         2012.0             2000.0  149000.0
# 2      2        Opel     Zafira A         2004.0             1600.0   99000.0
# 3      3     Hyundai        i10 I         2008.0             1100.0   93000.0
# 4      4  Volkswagen           CC         2010.0             1968.0  127428.0
# ..   ...         ...          ...            ...                ...       ...
# 995  995  Alfa Romeo          159         2009.0             2387.0  182000.0
# 996  996       Škoda     Fabia II         2012.0             1200.0   42700.0
# 997  997     Renault        Modus         2004.0             1200.0  168111.0
# 998  998        Audi        A3 8L         2000.0             1595.0  226500.0
# 999  999       Volvo      XC 60 I         2016.0             1969.0   13617.0
#
#          cena     wojewodztwo
# ...

# %% [markdown]
# Wyświetlanie 100 wierszy

# %%
df.head(10)
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
# 5   5        Fiat          500         2014.0    Elektryczny
# 6   6      Nissan    X-Trail I         2004.0         Diesel
# 7   7        Seat    Toledo II         2000.0        Benzyna
# 8   8  Volkswagen           CC         2014.0         Diesel
# 9   9      Nissan         Juke         2016.0        Benzyna
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# ...

# %% [markdown]
# Grupowanie

# %%
df.groupby(by="marka").mean()
# Out:
#                        id  rok_produkcji  pojemnosc_silnika       przebieg  \
# marka
# Alfa Romeo     516.600000    2003.400000        2037.400000  206200.000000
# Audi           483.128571    2009.171429        2162.414286  146606.400000
# BMW            523.045455    2008.727273        2267.621212  147909.151515
# Chevrolet      560.545455    2006.000000        2677.181818  150101.909091
# Chrysler       532.000000    2002.000000        2736.000000  112070.000000
# Citroën        476.325000    2007.475000        1606.425000  163401.175000
# Dacia          396.600000    2014.200000        1327.200000   47763.600000
# Daewoo         453.000000    1998.000000        1295.500000  160750.000000
# Daihatsu       919.000000    2007.000000        1595.000000  105060.000000
# Dodge          698.600000    2008.400000        2123.000000  137500.000000
# Fiat           595.969697    2008.606061        1487.000000  133163.000000
# ...

# %% [markdown]
# Zapytanie

# %%
df.query('cena < 10000')
# Out:
#       id    marka       model  rok_produkcji rodzaj_silnika  \
# 2      2     Opel    Zafira A         2004.0    Benzyna+CNG
# 7      7     Seat   Toledo II         2000.0        Benzyna
# 16    16     Ford  Mondeo Mk3         2003.0         Diesel
# 31    31     Fiat     Doblo I         2002.0        Benzyna
# 34    34  Citroën    Xsara II         2002.0        Benzyna
# ..   ...      ...         ...            ...            ...
# 943  943    Mazda       626 V         2001.0        Benzyna
# 965  965  Peugeot   Partner I         2003.0        Benzyna
# 975  975     Opel     Astra G         1998.0    Benzyna+LPG
# 984  984  Renault   Laguna II         2001.0        Benzyna
# 998  998     Audi       A3 8L         2000.0        Benzyna
#
#      pojemnosc_silnika  przebieg    cena     wojewodztwo
# 2               1600.0   99000.0  9800.0        Opolskie
# 7               1800.0  140700.0  8150.0       Pomorskie
# 16              2000.0  180000.0  7200.0     Małopolskie
# ...

# %% [markdown]
# Suma wszystkich samochodów

# %%
df.filter(items=['cena']).sum()
# Out:
# cena    51942181.0
# dtype: float64

# %% [markdown]
# Ilość poszczególnych rekordów danych marek

# %%
df['marka'].value_counts()
# Out:
# Opel             105
# Volkswagen        92
# Audi              70
# BMW               66
# Mercedes-Benz     59
# Ford              59
# Renault           59
# Toyota            49
# Peugeot           41
# Citroën           40
# Škoda             36
# Fiat              33
# Nissan            33
# Hyundai           31
# Honda             25
# Kia               25
# Volvo             24
# Mazda             21
# Seat              20
# Mitsubishi        18
# Suzuki            16
# Mini              11
# Chevrolet         11
# Lexus              7
# Jeep               6
# Dacia              5
# Land Rover         5
# Dodge              5
# Alfa Romeo         5
# SsangYong          3
# Saab               3
# Daewoo             2
# Infiniti           2
# Smart              2
# Porsche            2
# Jaguar             2
# Pontiac            1
# Subaru             1
# Daihatsu           1
# Ligier             1
# Maserati           1
# Lancia             1
# Chrysler           1
# ...

# %% [markdown]
# Najniższy przebieg silnika

# %%
df.filter(items=['przebieg']).min()
# Out:
# przebieg    1.0
# dtype: float64

# %%
df.expanding()
# Out:
# Expanding [min_periods=1,center=False,axis=0]
